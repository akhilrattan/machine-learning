# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilrattan/machine-learning/blob/main/cnn_training_final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Colab Notebooks'   Research_Assignment   Untitled0.ipynb
#  cropped_gt	    results		 'Untitled document.gdoc'
#  cropped_gt_2.zip  'Resume (1).gdoc'
#  models		    Resume.gdoc

# %%
zip_path = "/content/drive/MyDrive/cropped_gt_2.zip"

# %%
# !unzip -q "/content/drive/MyDrive/cropped_gt_2.zip" -d "/content/cropped_gt_cnn"
# Out:
# replace /content/cropped_gt_cnn/__MACOSX/._cropped_gt_2? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/._valid? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/._test? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/._train? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/valid/._paper? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/valid/._metal? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/valid/._cardboard? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/valid/._trash? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/cropped_gt_cnn/__MACOSX/cropped_gt_2/valid/._glass? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# ...

# %%
# !find /content/drive/MyDrive -type d -name "cropped_gt"

# %%
# !rsync -a "/content/drive/MyDrive/cropped_gt" /content/

# %%
from pathlib import Path

dataset = Path("/content/cropped_gt_cnn/cropped_gt_2")

print(dataset.exists())
print((dataset / "train").exists())
print((dataset / "valid").exists())
print((dataset / "test").exists())
# Out:
# True
# True
# True
# True

# %%
# !git clone https://github.com/akhilrattan/yolo-project.git
# Out:
# Cloning into 'yolo-project'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 73 (delta 30), reused 62 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 19.91 MiB | 36.86 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
import os

os.environ["CNN_DATASET"] = "/content/cropped_gt_cnn/cropped_gt_2"

# %%
# !pip install torch torchvision matplotlib pandas scikit-learn tqdm

# %%
# %cd /content/yolo-project
# Out:
# /content/yolo-project

# %%
# !python -m cnn.train
# Out:
# ...
# CNN TRAINING
# ...
#
# Epoch 1/40
# 100% 55/55 [00:09<00:00,  5.65it/s]
# Train Loss : 1.3101
# Val Loss   : 0.9996
# Train Acc  : 0.5606
# Val Acc    : 0.7500
# ✓ Best Model Saved
#
# Epoch 2/40
# 100% 55/55 [00:09<00:00,  6.00it/s]
# Train Loss : 0.8882
# Val Loss   : 0.7907
# Train Acc  : 0.7359
# Val Acc    : 0.7760
# ✓ Best Model Saved
#
# Epoch 3/40
# 100% 55/55 [00:10<00:00,  5.08it/s]
# Train Loss : 0.7369
# Val Loss   : 0.6948
# Train Acc  : 0.7712
# Val Acc    : 0.8040
# ✓ Best Model Saved
#
# Epoch 4/40
# 100% 55/55 [00:09<00:00,  5.59it/s]
# Train Loss : 0.6499
# Val Loss   : 0.6203
# Train Acc  : 0.7951
# Val Acc    : 0.8300
# ✓ Best Model Saved
#
# Epoch 5/40
# 100% 55/55 [00:09<00:00,  5.57it/s]
# Train Loss : 0.5999
# Val Loss   : 0.5842
# Train Acc  : 0.8201
# Val Acc    : 0.8480
# ✓ Best Model Saved
#
# Epoch 6/40
# 100% 55/55 [00:08<00:00,  6.15it/s]
# Train Loss : 0.5669
# Val Loss   : 0.5580
# Train Acc  : 0.8236
# Val Acc    : 0.8400
# ✓ Best Model Saved
#
# ...

# %%
# !cp -r /content/yolo-project/models /content/drive/MyDrive/
# !cp -r /content/yolo-project/results /content/drive/MyDrive/

# %%
# !find /content -name "best_model.pth"
# Out:
# /content/drive/MyDrive/models/cnn_weights/best_model.pth
